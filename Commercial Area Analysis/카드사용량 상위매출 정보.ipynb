# %%
from geoband.API import *
import pandas as pd
GetCompasData('SBJ_2012_002', '17', '17.용인시_소상공인_매출정보.csv')
df = pd.read_csv('17.용인시_소상공인_매출정보.csv')

# %% [markdown]
# # 카드 사용자 나이대별 전처리
# 10대, 20대, 30대 ~ 70대 나이대별로 필요한열만 들고와, 매출액기준으로 전처리하기

# %% [markdown]
# 2017년

# %%
#10대 2017년 1분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201703','ws_cnt', 'age30_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='age30_ratio', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201703  ws_cnt  age30_ratio indcd_a_yn  \
# 24   다사61ba24aa                   836       5        62.17        NaN
# 372  다사66ab19ab                     0      10        51.72        NaN
# 19   다사61ba15bb                  4809       7        46.16        NaN
# 127  다사63ab14ab                  6881      25        46.15        NaN
# 407  다사67aa16bb                   548      10        45.05        NaN
# 39   다사61bb20aa                   970       9        44.26        NaN
# 724  다사76ba21bb                   496       5        43.67        NaN
# 339  다사65bb13bb                     0      11        42.14        NaN
# 357  다사66aa19ab                     0      12        42.07        NaN
# 178  다사64aa25bb                  1281      12        41.64        NaN
# 220  다사64ba26ab                   509      18        40.26        NaN
# 102  다사62bb14aa                  2328       6        39.99        NaN
# ...

# %%
#10대 2017년 2분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201706','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201706', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201706  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                282903     325         3.14        NaN
# 350  다사65bb24ba                142341     263         0.73        NaN
# 41   다사61bb22aa                114761     253         1.21        NaN
# 175  다사64aa25aa                108027     241         4.11        NaN
# 470  다사69aa19bb                 94182     247         1.34        NaN
# 118  다사63aa23aa                 89352     160         2.04        NaN
# 312  다사65ab25ba                 87236      55         0.21        NaN
# 96   다사62ba23bb                 78000     118         0.85        NaN
# 480  다사69ab19bb                 77179     184         1.48        NaN
# 196  다사64ab25aa                 76886     273         1.05        NaN
# 58   다사62aa19bb                 74899     187         0.46        NaN
# 173  다사64aa24ba                 73196      30         2.18        NaN
# ...

# %%
#10대 2017년 3분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201709','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201709', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201709  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                315202     325         3.14        NaN
# 350  다사65bb24ba                147707     263         0.73        NaN
# 41   다사61bb22aa                122800     253         1.21        NaN
# 175  다사64aa25aa                114036     241         4.11        NaN
# 470  다사69aa19bb                104377     247         1.34        NaN
# 118  다사63aa23aa                 91538     160         2.04        NaN
# 480  다사69ab19bb                 81416     184         1.48        NaN
# 196  다사64ab25aa                 80308     273         1.05        NaN
# 96   다사62ba23bb                 79804     118         0.85        NaN
# 312  다사65ab25ba                 77173      55         0.21        NaN
# 499  다사69bb20ab                 76114     180         1.17        NaN
# 173  다사64aa24ba                 75644      30         2.18        NaN
# ...

# %%
#10대 2017년 4분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201712','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201712', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201712  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                298687     325         3.14        NaN
# 350  다사65bb24ba                150960     263         0.73        NaN
# 41   다사61bb22aa                129452     253         1.21        NaN
# 175  다사64aa25aa                119167     241         4.11        NaN
# 470  다사69aa19bb                104103     247         1.34        NaN
# 312  다사65ab25ba                 97029      55         0.21        NaN
# 118  다사63aa23aa                 94785     160         2.04        NaN
# 72   다사62ab18ba                 85785      81         0.19        NaN
# 480  다사69ab19bb                 85701     184         1.48        NaN
# 173  다사64aa24ba                 83911      30         2.18        NaN
# 58   다사62aa19bb                 81428     187         0.46        NaN
# 599  다사73bb15aa                 80529     137         2.68        NaN
# ...

# %% [markdown]
# 10대 2018년

# %%
#10대 2018년 1분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201803','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201803', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201803  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                350818     325         3.14        NaN
# 350  다사65bb24ba                152182     263         0.73        NaN
# 41   다사61bb22aa                144805     253         1.21        NaN
# 175  다사64aa25aa                128588     241         4.11        NaN
# 470  다사69aa19bb                112969     247         1.34        NaN
# 196  다사64ab25aa                100170     273         1.05        NaN
# 118  다사63aa23aa                 99570     160         2.04        NaN
# 96   다사62ba23bb                 89993     118         0.85        NaN
# 58   다사62aa19bb                 88182     187         0.46        NaN
# 480  다사69ab19bb                 86438     184         1.48        NaN
# 312  다사65ab25ba                 85501      55         0.21        NaN
# 173  다사64aa24ba                 84322      30         2.18        NaN
# ...

# %%
#10대 2018년 2분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201806','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201806', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201806  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                345758     325         3.14        NaN
# 350  다사65bb24ba                152559     263         0.73        NaN
# 41   다사61bb22aa                152496     253         1.21        NaN
# 175  다사64aa25aa                131034     241         4.11        NaN
# 470  다사69aa19bb                110049     247         1.34        NaN
# 312  다사65ab25ba                108675      55         0.21        NaN
# 118  다사63aa23aa                 99883     160         2.04        NaN
# 58   다사62aa19bb                 98546     187         0.46        NaN
# 96   다사62ba23bb                 98374     118         0.85        NaN
# 480  다사69ab19bb                 97945     184         1.48        NaN
# 173  다사64aa24ba                 90626      30         2.18        NaN
# 196  다사64ab25aa                 87508     273         1.05        NaN
# ...

# %%
#10대 2018년 3분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201809','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201809', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201809  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                350271     325         3.14        NaN
# 41   다사61bb22aa                166956     253         1.21        NaN
# 350  다사65bb24ba                160491     263         0.73        NaN
# 175  다사64aa25aa                128166     241         4.11        NaN
# 470  다사69aa19bb                110872     247         1.34        NaN
# 480  다사69ab19bb                104699     184         1.48        NaN
# 118  다사63aa23aa                102330     160         2.04        NaN
# 96   다사62ba23bb                 98448     118         0.85        NaN
# 173  다사64aa24ba                 95830      30         2.18        NaN
# 58   다사62aa19bb                 88327     187         0.46        NaN
# 196  다사64ab25aa                 88237     273         1.05        NaN
# 312  다사65ab25ba                 84899      55         0.21        NaN
# ...

# %%
#10대 2018년 4분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201812','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201812', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201812  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                342338     325         3.14        NaN
# 41   다사61bb22aa                167603     253         1.21        NaN
# 350  다사65bb24ba                157229     263         0.73        NaN
# 175  다사64aa25aa                128215     241         4.11        NaN
# 470  다사69aa19bb                109786     247         1.34        NaN
# 312  다사65ab25ba                109055      55         0.21        NaN
# 118  다사63aa23aa                102282     160         2.04        NaN
# 58   다사62aa19bb                101818     187         0.46        NaN
# 173  다사64aa24ba                101668      30         2.18        NaN
# 480  다사69ab19bb                100855     184         1.48        NaN
# 96   다사62ba23bb                 96963     118         0.85        NaN
# 196  다사64ab25aa                 94016     273         1.05        NaN
# ...

# %% [markdown]
# 10대 2019년

# %%
#10대 2019년 1분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201903','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201903', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201903  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                371093     325         3.14        NaN
# 41   다사61bb22aa                171760     253         1.21        NaN
# 350  다사65bb24ba                165540     263         0.73        NaN
# 175  다사64aa25aa                135066     241         4.11        NaN
# 196  다사64ab25aa                118488     273         1.05        NaN
# 470  다사69aa19bb                115597     247         1.34        NaN
# 118  다사63aa23aa                104954     160         2.04        NaN
# 58   다사62aa19bb                102479     187         0.46        NaN
# 480  다사69ab19bb                 98238     184         1.48        NaN
# 96   다사62ba23bb                 94530     118         0.85        NaN
# 499  다사69bb20ab                 93831     180         1.17        NaN
# 312  다사65ab25ba                 92295      55         0.21        NaN
# ...

# %%
#10대 2019년 2분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201906','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201906', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201906  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                369640     325         3.14        NaN
# 41   다사61bb22aa                175144     253         1.21        NaN
# 350  다사65bb24ba                165304     263         0.73        NaN
# 175  다사64aa25aa                160001     241         4.11        NaN
# 470  다사69aa19bb                117447     247         1.34        NaN
# 312  다사65ab25ba                108000      55         0.21        NaN
# 118  다사63aa23aa                105890     160         2.04        NaN
# 96   다사62ba23bb                103773     118         0.85        NaN
# 480  다사69ab19bb                103635     184         1.48        NaN
# 196  다사64ab25aa                103537     273         1.05        NaN
# 58   다사62aa19bb                103467     187         0.46        NaN
# 324  다사65ba20aa                 96249     266         1.64        NaN
# ...

# %%
#10대 2019년 3분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201909','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201909', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201909  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                380420     325         3.14        NaN
# 41   다사61bb22aa                175294     253         1.21        NaN
# 350  다사65bb24ba                157545     263         0.73        NaN
# 175  다사64aa25aa                143327     241         4.11        NaN
# 470  다사69aa19bb                121422     247         1.34        NaN
# 118  다사63aa23aa                109223     160         2.04        NaN
# 480  다사69ab19bb                103869     184         1.48        NaN
# 96   다사62ba23bb                100039     118         0.85        NaN
# 196  다사64ab25aa                 96095     273         1.05        NaN
# 173  다사64aa24ba                 95247      30         2.18        NaN
# 499  다사69bb20ab                 93191     180         1.17        NaN
# 324  다사65ba20aa                 91867     266         1.64        NaN
# ...

# %%
#10대 2019년 4분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201912','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_201912', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201912  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                358543     325         3.14        NaN
# 41   다사61bb22aa                184086     253         1.21        NaN
# 375  다사66ab21ba                165180     112         1.25        NaN
# 350  다사65bb24ba                164435     263         0.73        NaN
# 175  다사64aa25aa                150382     241         4.11        NaN
# 470  다사69aa19bb                138358     247         1.34        NaN
# 118  다사63aa23aa                106759     160         2.04        NaN
# 480  다사69ab19bb                105112     184         1.48        NaN
# 312  다사65ab25ba                103588      55         0.21        NaN
# 196  다사64ab25aa                103229     273         1.05        NaN
# 58   다사62aa19bb                100976     187         0.46        NaN
# 324  다사65ba20aa                100363     266         1.64        NaN
# ...

# %% [markdown]
# 10대 2020년

# %%
#10대 2020년 1분기
df10 = df.loc[0:,['gid', 'sales_est_amt_202003','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_202003', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_202003  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                324286     325         3.14        NaN
# 375  다사66ab21ba                164987     112         1.25        NaN
# 41   다사61bb22aa                159796     253         1.21        NaN
# 350  다사65bb24ba                147604     263         0.73        NaN
# 175  다사64aa25aa                146578     241         4.11        NaN
# 470  다사69aa19bb                111246     247         1.34        NaN
# 196  다사64ab25aa                103062     273         1.05        NaN
# 118  다사63aa23aa                 97276     160         2.04        NaN
# 324  다사65ba20aa                 94290     266         1.64        NaN
# 480  다사69ab19bb                 93511     184         1.48        NaN
# 173  다사64aa24ba                 90355      30         2.18        NaN
# 96   다사62ba23bb                 89140     118         0.85        NaN
# ...

# %%
#10대 2020년 2분기
df10 = df.loc[0:,['gid', 'sales_est_amt_202006','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_202006', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_202006  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                301874     325         3.14        NaN
# 375  다사66ab21ba                161296     112         1.25        NaN
# 41   다사61bb22aa                160485     253         1.21        NaN
# 350  다사65bb24ba                139589     263         0.73        NaN
# 175  다사64aa25aa                138835     241         4.11        NaN
# 470  다사69aa19bb                117749     247         1.34        NaN
# 196  다사64ab25aa                103552     273         1.05        NaN
# 96   다사62ba23bb                 97191     118         0.85        NaN
# 324  다사65ba20aa                 93387     266         1.64        NaN
# 118  다사63aa23aa                 91547     160         2.04        NaN
# 312  다사65ab25ba                 89004      55         0.21        NaN
# 480  다사69ab19bb                 87743     184         1.48        NaN
# ...

# %%
#10대 2020년 3분기
df10 = df.loc[0:,['gid', 'sales_est_amt_202009','ws_cnt', 'age10_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn','indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='sales_est_amt_202009', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_202009  ws_cnt  age10_ratio indcd_a_yn  \
# 174  다사64aa24bb                286696     325         3.14        NaN
# 375  다사66ab21ba                177898     112         1.25        NaN
# 41   다사61bb22aa                151762     253         1.21        NaN
# 350  다사65bb24ba                143149     263         0.73        NaN
# 175  다사64aa25aa                124329     241         4.11        NaN
# 470  다사69aa19bb                103727     247         1.34        NaN
# 173  다사64aa24ba                 95861      30         2.18        NaN
# 96   다사62ba23bb                 95797     118         0.85        NaN
# 118  다사63aa23aa                 90155     160         2.04        NaN
# 196  다사64ab25aa                 88394     273         1.05        NaN
# 247  다사64bb24bb                 87341       6         0.03        NaN
# 312  다사65ab25ba                 85669      55         0.21        NaN
# ...

# %%
# 매출액 나이대 비율 보기
df_age = df.loc[0:,['gid', 'sales_est_amt_201703','ws_cnt', 'age10_ratio', 'age20_ratio','age30_ratio','age40_ratio','age50_ratio',
                  'age60_ratio', 'age70_ratio',]]
df_age.sort_values(by='sales_est_amt_201703', ascending = False)[:30]
# Out:
#             gid  sales_est_amt_201703  ws_cnt  age10_ratio  age20_ratio  \
# 174  다사64aa24bb                286192     325         3.14         7.61
# 350  다사65bb24ba                117646     263         0.73         4.98
# 41   다사61bb22aa                105097     253         1.21         9.12
# 175  다사64aa25aa                100916     241         4.11        11.93
# 470  다사69aa19bb                 92488     247         1.34         8.19
# 196  다사64ab25aa                 89956     273         1.05         7.83
# 118  다사63aa23aa                 88324     160         2.04         4.40
# 58   다사62aa19bb                 72385     187         0.46         5.63
# 312  다사65ab25ba                 70114      55         0.21         4.76
# 96   다사62ba23bb                 69552     118         0.85         4.58
# 173  다사64aa24ba                 68806      30         2.18         6.94
# 499  다사69bb20ab                 67972     180         1.17         3.53
# ...

# %%
#10대 2017년 1분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201903','ws_cnt', 'age40_ratio', 'indcd_a_yn', 'indcd_b_yn','indcd_c_yn','indcd_d_yn','indcd_e_yn',
          'indcd_f_yn','indcd_g_yn','indcd_h_yn','indcd_i_yn',]]
df10.sort_values(by='age40_ratio', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201903  ws_cnt  age40_ratio indcd_a_yn  \
# 491  다사69ba18bb                   569       6        73.31        NaN
# 508  다사70ab20ab                     0       5        64.88        NaN
# 170  다사64aa18ba                  4283      12        61.05        NaN
# 397  다사66bb22ab                   971      10        60.93        NaN
# 351  다사65bb25aa                  4075      10        58.57        NaN
# 332  다사65ba23ab                   924       5        58.34        NaN
# 217  다사64ba25ba                   691       6        58.11        NaN
# 374  다사66ab21ab                   678       8        57.34        NaN
# 285  다사65ab16bb                  5551      15        57.30        NaN
# 256  다사65aa16bb                 11454      33        56.92        NaN
# 499  다사69bb20ab                 93831     180        56.31        NaN
# 741  다사77ba26ab                   924       6        56.18        NaN
# ...

# %%
#10대 2017년 1분기
df10 = df.loc[0:,['gid', 'sales_est_amt_201903','ws_cnt', 'age40_ratio', 'indcd_j_yn','indcd_k_yn','indcd_l_yn','indcd_m_yn',
          'indcd_n_yn','indcd_o_yn','indcd_p_yn','indcd_q_yn','indcd_r_yn','indcd_s_yn','indcd_t_yn','indcd_u_yn']]
df10.sort_values(by='age40_ratio', ascending = False)[:20]
# Out:
#             gid  sales_est_amt_201903  ws_cnt  age40_ratio indcd_j_yn  \
# 491  다사69ba18bb                   569       6        73.31        NaN
# 508  다사70ab20ab                     0       5        64.88        NaN
# 170  다사64aa18ba                  4283      12        61.05        NaN
# 397  다사66bb22ab                   971      10        60.93        NaN
# 351  다사65bb25aa                  4075      10        58.57        NaN
# 332  다사65ba23ab                   924       5        58.34        NaN
# 217  다사64ba25ba                   691       6        58.11        NaN
# 374  다사66ab21ab                   678       8        57.34        NaN
# 285  다사65ab16bb                  5551      15        57.30        NaN
# 256  다사65aa16bb                 11454      33        56.92        NaN
# 499  다사69bb20ab                 93831     180        56.31          Y
# 741  다사77ba26ab                   924       6        56.18        NaN
# ...
