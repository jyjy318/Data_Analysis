# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:


from geoband.API import *
import pandas as pd
GetCompasData('SBJ_2012_002', '7', '7.용인시_유동인구.csv')
move = pd.read_csv('7.용인시_유동인구.csv')
move


# In[3]:


Time7to9 = []
Time7to9 = move.loc[0:,['lon','lat']]
Time7to9


# In[41]:


import numpy as np
Time7to9['7to9']= move['TMST_08']+move['TMST_09']


# In[42]:


Time7to9


# In[43]:


import folium
folium.__version__


# In[49]:


geo_data = '11.용인시_법정경계(시군구).geojson'
center = [37.223837, 127.222847]

Time7to9 = Time7to9.sort_values(['7to9'], ascending=[False])


# In[50]:


Time7to9


# In[51]:


Time7to9.to_csv('./월별/move7to9.csv')


# In[54]:


moveTime7to9 = pd.read_csv('./월별/move7to9.csv')


# In[55]:


moveTime7to9


# In[56]:


locTime7to9 = moveTime7to9.loc[0:15000,['lon','lat','7to9']]
locTime7to9


# In[57]:


geo_data = '11.용인시_법정경계(시군구).geojson'
center = [37.223837, 127.222847]

m = folium.Map(location=center, zoom_start=10)
for item in locTime7to9.index :
    lat = locTime7to9.loc[item, 'lat']
    long = locTime7to9.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime7to9.loc[item,'7to9']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[23]:


Time9to11 = []
Time9to11 = move.loc[0:,['lon','lat']]
Time9to11['9to11']= move['TMST_10']+move['TMST_11']
Time9to11


# In[25]:


geo_data2 = '11.용인시_법정경계(시군구).geojson'
center = [37.223837, 127.222847]

Time9to11 = Time9to11.sort_values(['9to11'], ascending=[False])


# In[29]:


Time9to11.to_csv('./월별/move9to11.csv')
moveTime9to11 = pd.read_csv('./월별/move9to11.csv')
moveTime9to11


# In[31]:


locTime9to11 = moveTime9to11.loc[0:15000,['lon','lat','9to11']]
locTime9to11


# In[39]:


m = folium.Map(location=center, zoom_start=10)
for item in locTime9to11.index :
    lat = locTime9to11.loc[item, 'lat']
    long = locTime9to11.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime9to11.loc[item,'9to11']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[35]:


Time11to13 = []
Time11to13 = move.loc[0:,['lon','lat']]
Time11to13['11to13']= move['TMST_12']+move['TMST_13']
Time11to13


# In[38]:


Time11to13 = Time11to13.sort_values(['11to13'], ascending=[False])
Time11to13


# In[40]:


Time11to13.to_csv('./월별/move11to13.csv')
moveTime11to13 = pd.read_csv('./월별/move11to13.csv')
moveTime11to13


# In[62]:


locTime11to13 = moveTime11to13.loc[0:15000,['lon','lat','11to13']]
locTime11to13


# In[74]:


m = folium.Map(location=center, zoom_start=10)
for item in locTime11to13.index :
    lat = locTime11to13.loc[item, 'lat']
    long = locTime11to13.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime11to13.loc[item,'11to13']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[68]:


Time13to15 = []
Time13to15 = move.loc[0:,['lon','lat']]
Time13to15['13to15']= move['TMST_14']+move['TMST_15']
Time13to15


# In[70]:


Time13to15 = Time13to15.sort_values(['13to15'], ascending=[False])
Time13to15


# In[71]:


Time13to15.to_csv('./월별/move13to15.csv')
moveTime13to15 = pd.read_csv('./월별/move13to15.csv')
moveTime13to15


# In[73]:


locTime13to15 = moveTime13to15.loc[0:15000,['lon','lat','13to15']]
locTime13to15


# In[75]:


m = folium.Map(location=center, zoom_start=10)
for item in locTime13to15.index :
    lat = locTime13to15.loc[item, 'lat']
    long = locTime13to15.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime13to15.loc[item,'13to15']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[76]:


Time15to17 = []
Time15to17 = move.loc[0:,['lon','lat']]
Time15to17['15to17']= move['TMST_16']+move['TMST_17']
Time15to17


# In[77]:


Time15to17 = Time15to17.sort_values(['15to17'], ascending=[False])
Time15to17


# In[78]:


Time15to17.to_csv('./월별/move15to17.csv')
moveTime15to17 = pd.read_csv('./월별/move15to17.csv')
moveTime15to17


# In[79]:


locTime15to17 = moveTime15to17.loc[0:15000,['lon','lat','15to17']]
locTime15to17


# In[80]:


m = folium.Map(location=center, zoom_start=10)
for item in locTime15to17.index :
    lat = locTime15to17.loc[item, 'lat']
    long = locTime15to17.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime15to17.loc[item,'15to17']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[81]:


Time17to19 = []
Time17to19 = move.loc[0:,['lon','lat']]
Time17to19['17to19']= move['TMST_18']+move['TMST_19']
Time17to19


# In[82]:


Time17to19 = Time17to19.sort_values(['17to19'], ascending=[False])
Time17to19


# In[83]:


Time17to19.to_csv('./월별/move17to19.csv')
moveTime17to19 = pd.read_csv('./월별/move17to19.csv')
moveTime17to19


# In[84]:


locTime17to19 = moveTime17to19.loc[0:15000,['lon','lat','17to19']]
locTime17to19


# In[85]:


m = folium.Map(location=center, zoom_start=10)
for item in locTime17to19.index :
    lat = locTime17to19.loc[item, 'lat']
    long = locTime17to19.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime17to19.loc[item,'17to19']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[86]:


Time19to21 = []
Time19to21 = move.loc[0:,['lon','lat']]
Time19to21['19to21']= move['TMST_20']+move['TMST_21']
Time19to21


# In[87]:


Time19to21 = Time19to21.sort_values(['19to21'], ascending=[False])
Time19to21


# In[88]:


Time19to21.to_csv('./월별/move19to21.csv')
moveTime19to21 = pd.read_csv('./월별/move19to21.csv')
moveTime19to21


# In[89]:


locTime19to21 = moveTime19to21.loc[0:15000,['lon','lat','19to21']]
locTime19to21


# In[90]:


m = folium.Map(location=center, zoom_start=10)
for item in locTime19to21.index :
    lat = locTime19to21.loc[item, 'lat']
    long = locTime19to21.loc[item, 'lon']
    
    folium.CircleMarker([lat,long],
                       radius = locTime19to21.loc[item,'19to21']/150,
                       color = 'blue',
                       fill= True).add_to(m)
m


# In[ ]:
