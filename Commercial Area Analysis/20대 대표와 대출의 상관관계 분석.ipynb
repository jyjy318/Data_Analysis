# %%
import pandas as pd

# %%
df17=pd.read_csv('17.용인시_소상공인_매출정보.csv')

# %%
df17.columns
# Out:
# Index(['gid', 'ws_cnt', 'found_age_1', 'found_age_2', 'found_age_3',
#        'found_age_4', 'found_age_5', 'found_age_6', 'runout_cnt',
#        'smbiz_yn_cnt', 'rpr_per_gender_m', 'rpr_per_gender_f',
#        'rpr_per_age_bin_10', 'rpr_per_age_bin_20', 'rpr_per_age_bin_30to50',
#        'rpr_per_age_bin_50over', 'sme_loan_cnt', 'sme_loan_y_1',
#        'sme_loan_y_2', 'sme_loan_y_3', 'sme_loan_y_4', 'sme_loan_y_5',
#        'sme_loan_y_6', 'sales_est_amt_201703', 'sales_est_amt_201706',
#        'sales_est_amt_201709', 'sales_est_amt_201712', 'sales_est_amt_201803',
#        'sales_est_amt_201806', 'sales_est_amt_201809', 'sales_est_amt_201812',
#        'sales_est_amt_201903', 'sales_est_amt_201906', 'sales_est_amt_201909',
#        'sales_est_amt_201912', 'sales_est_amt_202003', 'sales_est_amt_202006',
#        'sales_est_amt_202009', 'age10_ratio', 'age20_ratio', 'age30_ratio',
#        'age40_ratio', 'age50_ratio', 'age60_ratio', 'age70_ratio',
# ...

# %%
df17_1703= df17.loc[0:,[ 'sales_est_amt_201703','sme_loan_cnt',]]

# %%
corr = df17_.corr(method = 'pearson')
corr
# Out:
#                       sales_est_amt_201703  sme_loan_cnt
# sales_est_amt_201703              1.000000      0.843111
# sme_loan_cnt                      0.843111      1.000000

# %%
df17_= df17.loc[0:,['gid', 'sales_est_amt_201706','sme_loan_cnt',]]

# %%
corr = df17_.corr(method = 'pearson')
corr
# Out:
#                       sales_est_amt_201706  sme_loan_cnt
# sales_est_amt_201706              1.000000      0.846112
# sme_loan_cnt                      0.846112      1.000000

# %%
df17_= df17.loc[0:,['sales_est_amt_201709','sme_loan_cnt',]]
corr = df17_.corr(method = 'pearson')
corr
# Out:
#                       sales_est_amt_201709  sme_loan_cnt
# sales_est_amt_201709              1.000000      0.848568
# sme_loan_cnt                      0.848568      1.000000

# %%
df17_1703.to_csv('./월별/df17_1703.csv') #csv파일로 생성

# %%
df17_1703
# Out:
#      sales_est_amt_201703  sme_loan_cnt
# 0                    1682             2
# 1                    2563             3
# 2                    5180             3
# 3                    1645             5
# 4                     216             2
# ..                    ...           ...
# 802                   264             2
# 803                  1118             4
# 804                  1453             0
# 805                  1165             5
# 806                   336             2
#
# [807 rows x 2 columns]

# %%
#창업found_age와 대출 사이의 상관관계 
df17_ageloantotal= df17.loc[0:,[ 'found_age_1', 'found_age_2', 'found_age_3',
       'found_age_4', 'found_age_5', 'found_age_6','sme_loan_cnt', 'sme_loan_y_1',
       'sme_loan_y_2', 'sme_loan_y_3', 'sme_loan_y_4', 'sme_loan_y_5',
       'sme_loan_y_6',]]

# %%
corrtotal=df17_ageloantotal.corr(method = 'pearson')
corrtotal
# Out:
#               found_age_1  found_age_2  found_age_3  found_age_4  found_age_5  \
# found_age_1      1.000000     0.789351     0.753333     0.678665     0.666884
# found_age_2      0.789351     1.000000     0.833387     0.763192     0.751564
# found_age_3      0.753333     0.833387     1.000000     0.761452     0.697991
# found_age_4      0.678665     0.763192     0.761452     1.000000     0.816994
# found_age_5      0.666884     0.751564     0.697991     0.816994     1.000000
# found_age_6      0.636626     0.745838     0.696421     0.819194     0.822202
# sme_loan_cnt     0.745635     0.873413     0.827318     0.874680     0.870110
# sme_loan_y_1     0.637862     0.682888     0.660319     0.653066     0.618945
# sme_loan_y_2     0.647920     0.728519     0.668963     0.657480     0.672753
# sme_loan_y_3     0.708374     0.801522     0.759342     0.773409     0.774127
# sme_loan_y_4     0.720358     0.833397     0.812590     0.845876     0.836721
# ...

# %%
corrtotal.head(6)
# Out:
#              found_age_1  found_age_2  found_age_3  found_age_4  found_age_5  \
# found_age_1     1.000000     0.789351     0.753333     0.678665     0.666884
# found_age_2     0.789351     1.000000     0.833387     0.763192     0.751564
# found_age_3     0.753333     0.833387     1.000000     0.761452     0.697991
# found_age_4     0.678665     0.763192     0.761452     1.000000     0.816994
# found_age_5     0.666884     0.751564     0.697991     0.816994     1.000000
# found_age_6     0.636626     0.745838     0.696421     0.819194     0.822202
#
#              found_age_6  sme_loan_cnt  sme_loan_y_1  sme_loan_y_2  \
# found_age_1     0.636626      0.745635      0.637862      0.647920
# found_age_2     0.745838      0.873413      0.682888      0.728519
# found_age_3     0.696421      0.827318      0.660319      0.668963
# found_age_4     0.819194      0.874680      0.653066      0.657480
# found_age_5     0.822202      0.870110      0.618945      0.672753
# ...

# %% [markdown]
# # 20대 대표와 대출의 상관관계 ==> 대출은 하지만 대출 비용은 크지 않다!

# %%
#20대 대표와 대출의 상관관계
df17_20= df17.loc[0:,[ 'rpr_per_age_bin_20','sme_loan_cnt', 'sme_loan_y_1',
       'sme_loan_y_2', 'sme_loan_y_3', 'sme_loan_y_4', 'sme_loan_y_5',
       'sme_loan_y_6',]]

# %%
corr17_20 = df17_20.corr(method = 'pearson')
corr17_20
# Out:
#                     rpr_per_age_bin_20  sme_loan_cnt  sme_loan_y_1  \
# rpr_per_age_bin_20            1.000000      0.720219      0.568574
# sme_loan_cnt                  0.720219      1.000000      0.697030
# sme_loan_y_1                  0.568574      0.697030      1.000000
# sme_loan_y_2                  0.612777      0.738652      0.577483
# sme_loan_y_3                  0.687193      0.837527      0.634001
# sme_loan_y_4                  0.695481      0.952577      0.652492
# sme_loan_y_5                  0.669318      0.923622      0.582547
# sme_loan_y_6                  0.563093      0.903840      0.511930
#
#                     sme_loan_y_2  sme_loan_y_3  sme_loan_y_4  sme_loan_y_5  \
# rpr_per_age_bin_20      0.612777      0.687193      0.695481      0.669318
# sme_loan_cnt            0.738652      0.837527      0.952577      0.923622
# sme_loan_y_1            0.577483      0.634001      0.652492      0.582547
# ...

# %%
df17_foundrun= df17.loc[0:,[ 'found_age_1', 'found_age_2', 'found_age_3',
       'found_age_4', 'found_age_5', 'found_age_6','runout_cnt',]]

# %%
corr17_foundrun = df17_foundrun.corr(method = 'pearson')
corr17_foundrun
# Out:
#              found_age_1  found_age_2  found_age_3  found_age_4  found_age_5  \
# found_age_1     1.000000     0.789351     0.753333     0.678665     0.666884
# found_age_2     0.789351     1.000000     0.833387     0.763192     0.751564
# found_age_3     0.753333     0.833387     1.000000     0.761452     0.697991
# found_age_4     0.678665     0.763192     0.761452     1.000000     0.816994
# found_age_5     0.666884     0.751564     0.697991     0.816994     1.000000
# found_age_6     0.636626     0.745838     0.696421     0.819194     0.822202
# runout_cnt      0.664319     0.754536     0.721557     0.765781     0.775292
#
#              found_age_6  runout_cnt
# found_age_1     0.636626    0.664319
# found_age_2     0.745838    0.754536
# found_age_3     0.696421    0.721557
# found_age_4     0.819194    0.765781
# found_age_5     0.822202    0.775292
# found_age_6     1.000000    0.739250
# runout_cnt      0.739250    1.000000
