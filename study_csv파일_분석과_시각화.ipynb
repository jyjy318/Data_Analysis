# %%
import pandas as pd

# %%
names1880 = pd.read_csv('/content/drive/My Drive/블렌디드 러닝/Data/yob1880.txt',
                        names=['names','sex','births'])

# %%
names1880
# Out:
#           names sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# ...         ...  ..     ...
# 1995     Woodie   M       5
# 1996     Worthy   M       5
# 1997     Wright   M       5
# 1998       York   M       5
# 1999  Zachariah   M       5
#
# [2000 rows x 3 columns]

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
years=range(1880,2011)
pieces = []
colums = ['name', 'sex', 'births']

# %%
for year in years:
  path = '/content/drive/My Drive/블렌디드 러닝/Data/yob%d.txt' %year
  frame = pd.read_csv(path, names = colums)
  frame['year'] = year
  pieces.append(frame)

  names = pd.concat(pieces, ignore_index=True)

# %%
#%d는 정수형을 치환할 때 사용하는 치환 구문입니다

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# ...            ...  ..     ...   ...
# 1690779    Zymaire   M       5  2010
# 1690780     Zyonne   M       5  2010
# 1690781  Zyquarius   M       5  2010
# 1690782      Zyran   M       5  2010
# 1690783      Zzyzx   M       5  2010
#
# [1690784 rows x 4 columns]

# %%
total_births = names.pivot_table('births', index='year',
                                 columns='sex', aggfunc=sum)
total_births.tail()
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %%
import matplotlib.pyplot as plt

# %%
total_births.plot(title = "Total births by sex and year")

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,2)
ax1 = fig.add_subplot(2,2,3)

from numpy.random import randn
plt.plot(randn(50).sumsum(),'k--')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-607e2ae204af> in <module>()
#       5
#       6 from numpy.random import randn
# ----> 7 plt.plot(randn(50).sumsum(),'k--')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sumsum'
